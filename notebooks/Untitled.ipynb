# %%
from pathlib import Path

print(
    (
        Path("../data/processed")
        / "seller_analytics.csv"
    ).resolve()
)
# Out:
# /Users/saadmaher/Desktop/Data Science/Project portfolio/olist-ecommerce-business-analytics/data/processed/seller_analytics.csv
